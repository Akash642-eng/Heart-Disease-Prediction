# %% [markdown]
# Dataset_Preview

# %%
import os
import warnings
import matplotlib.pyplot as plt
import pandas as pd


try:
	df
except NameError:
	possible_paths = ['../data/heart.csv', './data/heart.csv', '../heart.csv', 'heart.csv']
	for p in possible_paths:
		if os.path.exists(p):
			df = pd.read_csv(p)
			break
	else:
		warnings.warn(
			"DataFrame 'df' was not defined and no CSV found in ../data or current directory. "
			"Using a small placeholder DataFrame so the preview cell can run."
		)
		df = pd.DataFrame({
			'age': [63, 67, 67, 37, 41],
			'sex': [1, 1, 1, 1, 0],
			'cp': [1, 4, 4, 3, 2],
		})
		
os.makedirs('../images', exist_ok=True)

plt.figure(figsize=(10, 2))
plt.axis('off')
plt.table(cellText=df.head().values, colLabels=df.columns, loc='center')
plt.savefig('../images/dataset_preview.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# Target_Distribution

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

if 'df' not in globals():
	possible_paths = ['heart.csv', 'heart_disease.csv', 'data/heart.csv', '../data/heart.csv', '../heart.csv']
	for p in possible_paths:
		if os.path.exists(p):
			df = pd.read_csv(p)
			break
	else:
		raise NameError(
			"DataFrame 'df' is not defined and no dataset file was found. "
			"Please define `df` (e.g., df = pd.read_csv('path/to/your.csv')) or place the dataset "
			"as one of: " + ", ".join(possible_paths)
		)

plt.figure(figsize=(6,4))
sns.countplot(x='target', data=df)
plt.title('Heart Disease Distribution')
plt.xlabel('Target (0 = Healthy, 1 = Disease)')
plt.ylabel('Count')
plt.savefig('../images/target_distribution.png')
plt.show()

# %% [markdown]
# Correlation_Heatmap

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.savefig('../images/correlation_heatmap.png')
plt.show()

# %% [markdown]
# Age vs Cholesterol

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

if 'df' not in globals():
	possible_paths = ['heart.csv', 'heart_disease.csv', 'data/heart.csv', '../data/heart.csv', '../heart.csv']
	for p in possible_paths:
		if os.path.exists(p):
			df = pd.read_csv(p)
			break
	else:
		raise NameError(
			"DataFrame 'df' is not defined and no dataset file was found. "
			"Please define `df` (e.g., df = pd.read_csv('path/to/your.csv')) or place the dataset "
			"as one of: " + ", ".join(possible_paths)
		)

plt.figure(figsize=(6,4))
sns.scatterplot(x='age', y='chol', hue='target', data=df)
plt.title('Age vs Cholesterol')
plt.savefig('../images/age_vs_cholesterol.png')
plt.show()

# %% [markdown]
# Model_Accuracy

# %%
import matplotlib.pyplot as plt

try:
    train_accuracy = accuracy
except NameError:
    train_accuracy = float("nan") 
test_accuracy = model_obj.score(X_test_obj, y_test_obj)

plt.figure(figsize=(5,4))
plt.bar(['Train Accuracy', 'Test Accuracy'], 
        [train_accuracy, test_accuracy])
plt.ylim(0,1)
plt.title('Model Accuracy (Logistic Regression)')
plt.ylabel('Accuracy')

plt.savefig('../images/model_accuracy.png')
plt.show()
